# %%
import numpy as np
import pandas as pd
import seaborn as sns

sns.set(style="ticks", color_codes=True)
import matplotlib.pyplot as plt
plt.style.use('classic')
# %matplotlib inline

# %% [markdown]
# # Import Data

# %%
  #Velocities average for DNS datasets
dfv0 = pd.read_csv('C://Users/pmbw/Leeds/Development/datasets/velocities/velocities_000000_000.dat',
           header=None, delim_whitespace=True, engine='python')
dfv1 = pd.read_csv('C://Users/pmbw/Leeds/Development/datasets/velocities/velocities_000000_001.dat',
           header=None, delim_whitespace=True, engine='python')
dfv2 = pd.read_csv('C://Users/pmbw/Leeds/Development/datasets/velocities/velocities_000000_002.dat',
           header=None, delim_whitespace=True, engine='python')
dfv3 = pd.read_csv('C://Users/pmbw/Leeds/Development/datasets/velocities/velocities_000000_003.dat',
           header=None, delim_whitespace=True, engine='python')
dfv4 = pd.read_csv('C://Users/pmbw/Leeds/Development/datasets/velocities/velocities_000000_004.dat',
           header=None, delim_whitespace=True, engine='python')
dfv5 = pd.read_csv('C://Users/pmbw/Leeds/Development/datasets/velocities/velocities_000000_005.dat',
           header=None, delim_whitespace=True, engine='python')
dfv6 = pd.read_csv('C://Users/pmbw/Leeds/Development/datasets/velocities/velocities_000000_006.dat',
           header=None, delim_whitespace=True, engine='python')
dfv7 = pd.read_csv('C://Users/pmbw/Leeds/Development/datasets/velocities/velocities_000000_007.dat',
           header=None, delim_whitespace=True, engine='python')
dfv8 = pd.read_csv('C://Users/pmbw/Leeds/Development/datasets/velocities/velocities_000000_008.dat',
           header=None, delim_whitespace=True, engine='python')
dfv9 = pd.read_csv('C://Users/pmbw/Leeds/Development/datasets/velocities/velocities_000000_009.dat',
           header=None, delim_whitespace=True, engine='python')
dfv10 = pd.read_csv('C://Users/pmbw/Leeds/Development/datasets/velocities/velocities_000000_010.dat',
           header=None, delim_whitespace=True, engine='python')
dfv11 = pd.read_csv('C://Users/pmbw/Leeds/Development/datasets/velocities/velocities_000000_011.dat',
           header=None, delim_whitespace=True, engine='python')
  #RMS data

dfrms0 = pd.read_csv('C://Users/pmbw/Leeds/Development/datasets/velocities/rms_000000_000.dat',
           header=None, delim_whitespace=True, engine='python')
dfrms1 = pd.read_csv('C://Users/pmbw/Leeds/Development/datasets/velocities/rms_000000_001.dat',
           header=None, delim_whitespace=True, engine='python')
dfrms2 = pd.read_csv('C://Users/pmbw/Leeds/Development/datasets/velocities/rms_000000_002.dat',
           header=None, delim_whitespace=True, engine='python')
dfrms3 = pd.read_csv('C://Users/pmbw/Leeds/Development/datasets/velocities/rms_000000_003.dat',
           header=None, delim_whitespace=True, engine='python')
dfrms4 = pd.read_csv('C://Users/pmbw/Leeds/Development/datasets/velocities/rms_000000_004.dat',
           header=None, delim_whitespace=True, engine='python')
dfrms5 = pd.read_csv('C://Users/pmbw/Leeds/Development/datasets/velocities/rms_000000_005.dat',
           header=None, delim_whitespace=True, engine='python')
dfrms6 = pd.read_csv('C://Users/pmbw/Leeds/Development/datasets/velocities/rms_000000_006.dat',
           header=None, delim_whitespace=True, engine='python')
dfrms7 = pd.read_csv('C://Users/pmbw/Leeds/Development/datasets/velocities/rms_000000_007.dat',
           header=None, delim_whitespace=True, engine='python')
dfrms8 = pd.read_csv('C://Users/pmbw/Leeds/Development/datasets/velocities/rms_000000_008.dat',
           header=None, delim_whitespace=True, engine='python')
dfrms9 = pd.read_csv('C://Users/pmbw/Leeds/Development/datasets/velocities/rms_000000_009.dat',
           header=None, delim_whitespace=True, engine='python')
dfrms10 = pd.read_csv('C://Users/pmbw/Leeds/Development/datasets/velocities/rms_000000_010.dat',
           header=None, delim_whitespace=True, engine='python')
dfrms11 = pd.read_csv('C://Users/pmbw/Leeds/Development/datasets/velocities/rms_000000_011.dat',
           header=None, delim_whitespace=True, engine='python')


     #Previous DNS data
df = pd.read_csv('C://Leeds/Datasets_El_Khoury/Re361/360_Re_1.dat',
          skiprows=24, header=None, sep='\s\s+', engine='python') 
df.columns = ['OneMin_r', 'OneMin_rPlus','UzPlus','UzByUb', 'Ur_rmsPlus','Ut_rmsPlus','Uz_rmsPlus', 'UzUrPlus','dUzdrPlus']

# %%
  #Velocities average for DNS datasets
dfvRun00 = pd.read_csv('C://Users/pmbw/Leeds/Development/datasets/velocities1/velocities_000000_000.dat',
           header=None, delim_whitespace=True, engine='python')
dfvRun01 = pd.read_csv('C://Users/pmbw/Leeds/Development/datasets/velocities1/velocities_000000_001.dat',
           header=None, delim_whitespace=True, engine='python')
dfvRun02 = pd.read_csv('C://Users/pmbw/Leeds/Development/datasets/velocities1/velocities_000000_002.dat',
           header=None, delim_whitespace=True, engine='python')
dfvRun03 = pd.read_csv('C://Users/pmbw/Leeds/Development/datasets/velocities1/velocities_000000_003.dat',
           header=None, delim_whitespace=True, engine='python')
dfvRun04 = pd.read_csv('C://Users/pmbw/Leeds/Development/datasets/velocities1/velocities_000000_004.dat',
           header=None, delim_whitespace=True, engine='python')
dfvRun05 = pd.read_csv('C://Users/pmbw/Leeds/Development/datasets/velocities1/velocities_000000_005.dat',
           header=None, delim_whitespace=True, engine='python')
dfvRun06 = pd.read_csv('C://Users/pmbw/Leeds/Development/datasets/velocities1/velocities_000000_006.dat',
           header=None, delim_whitespace=True, engine='python')
dfvRun07 = pd.read_csv('C://Users/pmbw/Leeds/Development/datasets/velocities1/velocities_000000_007.dat',
           header=None, delim_whitespace=True, engine='python')
dfvRun08 = pd.read_csv('C://Users/pmbw/Leeds/Development/datasets/velocities1/velocities_000000_008.dat',
           header=None, delim_whitespace=True, engine='python')
dfvRun09 = pd.read_csv('C://Users/pmbw/Leeds/Development/datasets/velocities1/velocities_000000_009.dat',
           header=None, delim_whitespace=True, engine='python')
dfvRun010 = pd.read_csv('C://Users/pmbw/Leeds/Development/datasets/velocities1/velocities_000000_010.dat',
           header=None, delim_whitespace=True, engine='python')
dfvRun011 = pd.read_csv('C://Users/pmbw/Leeds/Development/datasets/velocities1/velocities_000000_011.dat',
           header=None, delim_whitespace=True, engine='python')
  #RMS data

dfrmsRun00 = pd.read_csv('C://Users/pmbw/Leeds/Development/datasets/velocities1/rms_000000_000.dat',
           header=None, delim_whitespace=True, engine='python')
dfrmsRun01 = pd.read_csv('C://Users/pmbw/Leeds/Development/datasets/velocities1/rms_000000_001.dat',
           header=None, delim_whitespace=True, engine='python')
dfrmsRun02 = pd.read_csv('C://Users/pmbw/Leeds/Development/datasets/velocities1/rms_000000_002.dat',
           header=None, delim_whitespace=True, engine='python')
dfrmsRun03 = pd.read_csv('C://Users/pmbw/Leeds/Development/datasets/velocities1/rms_000000_003.dat',
           header=None, delim_whitespace=True, engine='python')
dfrmsRun04 = pd.read_csv('C://Users/pmbw/Leeds/Development/datasets/velocities1/rms_000000_004.dat',
           header=None, delim_whitespace=True, engine='python')
dfrmsRun05 = pd.read_csv('C://Users/pmbw/Leeds/Development/datasets/velocities1/rms_000000_005.dat',
           header=None, delim_whitespace=True, engine='python')
dfrmsRun06 = pd.read_csv('C://Users/pmbw/Leeds/Development/datasets/velocities1/rms_000000_006.dat',
           header=None, delim_whitespace=True, engine='python')
dfrmsRun07 = pd.read_csv('C://Users/pmbw/Leeds/Development/datasets/velocities1/rms_000000_007.dat',
           header=None, delim_whitespace=True, engine='python')
dfrmsRun08 = pd.read_csv('C://Users/pmbw/Leeds/Development/datasets/velocities1/rms_000000_008.dat',
           header=None, delim_whitespace=True, engine='python')
dfrmsRun09 = pd.read_csv('C://Users/pmbw/Leeds/Development/datasets/velocities1/rms_000000_009.dat',
           header=None, delim_whitespace=True, engine='python')
dfrmsRun010 = pd.read_csv('C://Users/pmbw/Leeds/Development/datasets/velocities1/rms_000000_010.dat',
           header=None, delim_whitespace=True, engine='python')
dfrmsRun011 = pd.read_csv('C://Users/pmbw/Leeds/Development/datasets/velocities1/rms_000000_011.dat',
           header=None, delim_whitespace=True, engine='python')


dfrmsRun111 = [dfrmsRun00,dfrmsRun01, dfrmsRun02,dfrmsRun03,dfrmsRun04,dfrmsRun05,dfrmsRun06,dfrmsRun07,dfrmsRun08,dfrmsRun09,dfrmsRun010, dfrmsRun011]
df_avg_rmsrun1 = pd.concat([each.stack() for each in dfrmsRun111],axis=1)\
             .apply(lambda x:x.mean(),axis=1)\
             .unstack()

df_avg_rmsrun1.columns = ['point', 'x','y','z','men']

# %%
  #Velocities average for DNS datasets
dfvRun20 = pd.read_csv('C://Users/pmbw/Leeds/Development/datasets/velocities2/velocities_000000_000.dat',
           header=None, delim_whitespace=True, engine='python')
dfvRun21 = pd.read_csv('C://Users/pmbw/Leeds/Development/datasets/velocities2/velocities_000000_001.dat',
           header=None, delim_whitespace=True, engine='python')
dfvRun22 = pd.read_csv('C://Users/pmbw/Leeds/Development/datasets/velocities2/velocities_000000_002.dat',
           header=None, delim_whitespace=True, engine='python')
dfvRun23 = pd.read_csv('C://Users/pmbw/Leeds/Development/datasets/velocities2/velocities_000000_003.dat',
           header=None, delim_whitespace=True, engine='python')
dfvRun24 = pd.read_csv('C://Users/pmbw/Leeds/Development/datasets/velocities2/velocities_000000_004.dat',
           header=None, delim_whitespace=True, engine='python')
dfvRun25 = pd.read_csv('C://Users/pmbw/Leeds/Development/datasets/velocities2/velocities_000000_005.dat',
           header=None, delim_whitespace=True, engine='python')
dfvRun26 = pd.read_csv('C://Users/pmbw/Leeds/Development/datasets/velocities2/velocities_000000_006.dat',
           header=None, delim_whitespace=True, engine='python')
dfvRun27 = pd.read_csv('C://Users/pmbw/Leeds/Development/datasets/velocities2/velocities_000000_007.dat',
           header=None, delim_whitespace=True, engine='python')
dfvRun28 = pd.read_csv('C://Users/pmbw/Leeds/Development/datasets/velocities2/velocities_000000_008.dat',
           header=None, delim_whitespace=True, engine='python')
dfvRun29 = pd.read_csv('C://Users/pmbw/Leeds/Development/datasets/velocities2/velocities_000000_009.dat',
           header=None, delim_whitespace=True, engine='python')
dfvRun210 = pd.read_csv('C://Users/pmbw/Leeds/Development/datasets/velocities2/velocities_000000_010.dat',
           header=None, delim_whitespace=True, engine='python')
dfvRun211 = pd.read_csv('C://Users/pmbw/Leeds/Development/datasets/velocities2/velocities_000000_011.dat',
           header=None, delim_whitespace=True, engine='python')


dfRun2 = [dfvRun20,dfvRun21, dfvRun22,dfvRun23,dfvRun24,dfvRun25,dfvRun26, dfvRun27,dfvRun28,dfvRun29,dfvRun210,dfvRun211]
df_avg_dfRun2 = pd.concat([each.stack() for each in dfRun2],axis=1)\
             .apply(lambda x:x.mean(),axis=1)\
             .unstack()

df_avg_dfRun2.columns = ['point', 'x','y','z']
df_avg_dfRun2['yp'] = ((0.4995-df_avg_dfRun2.point)*361)*2
df_avg_dfRun2['u'] = (df_avg_dfRun2.z)*(5850/361)
df_avg_dfRun2['xx'] = (df_avg_dfRun2.x)*(5850/361)
df_avg_dfRun2['yy'] = (df_avg_dfRun2.y)*(5850/361)


df_avg_dfRun2['yrms'] = ((0.5-df_avg_dfRun2.point)*360)*2
df_avg_dfRun2['uzrms'] = df_avg_dfRun2.z *(5850/360)
df_avg_dfRun2['uxrms'] = df_avg_dfRun2.x *(5850/360)
df_avg_dfRun2['uyrms'] = df_avg_dfRun2.y *(5850/360)
#df_avg_rms['umenrms'] = df_avg_rms.men *(5850/361)
#df_avg_dfRun2['umenrms'] = np.sqrt(df_avg_dfRun2.men)*(5850/360)

# %%
df_avg_dfRun2
# Out:
#        point             x         y         z        yp          u        xx  \
# 0    0.00000  2.586897e-03  0.000074  1.267327  360.6390  20.537011  0.041921
# 1    0.00875 -1.469775e-04  0.000328  1.267177  354.3215  20.534579 -0.002382
# 2    0.01250 -2.297187e-04  0.000461  1.267020  351.6140  20.532035 -0.003723
# 3    0.02625 -1.532325e-04  0.000702  1.266062  341.6865  20.516512 -0.002483
# 4    0.02750 -2.179141e-04  0.000765  1.265897  340.7840  20.513838 -0.003531
# ..       ...           ...       ...       ...       ...        ...       ...
# 262  0.49500  1.516904e-05 -0.000561  0.114554    3.2490   1.856345  0.000246
# 263  0.49625  1.320435e-06  0.000049  0.069986    2.3465   1.134128  0.000021
# 264  0.49750  3.657314e-06 -0.000505  0.059780    1.4440   0.968730  0.000059
# 265  0.49875  1.720189e-07  0.000003  0.013697    0.5415   0.221963  0.000003
# 266  0.50000  0.000000e+00  0.000000  0.000000   -0.3610   0.000000  0.000000
#
# ...

# %% [markdown]
# # Mean axial velocity Uz+

# %%
ax = plt.gca()
# Set x logaritmic
ax.set_xscale('log')
plt.plot(df.OneMin_rPlus,df.UzPlus, color ='blue')
plt.plot(df_avg_dfRun2.yp,df_avg_dfRun2.u,color ='green')
plt.legend('a', ncol=2, loc='upper left');
plt.ylabel('Uz+')
plt.xlabel('(1-r)+')
plt.legend(['El Koury','simulation1' ], ncol=2, loc='upper left');

# %%
df.head()
# Out:
#    OneMin_r  OneMin_rPlus     UzPlus    UzByUb  Ur_rmsPlus  Ut_rmsPlus  \
# 0  1.000000    361.217889  20.605459  1.272318    0.670160    0.670160
# 1  0.987453    356.685512  20.604020  1.272229    0.670291    0.670406
# 2  0.975062    352.209927  20.599764  1.271966    0.670682    0.671152
# 3  0.962827    347.790423  20.592756  1.271534    0.671335    0.672413
# 4  0.950746    343.426295  20.583060  1.270935    0.672246    0.674192
#
#    Uz_rmsPlus      UzUrPlus     dUzdrPlus
# 0    0.828781  6.291752e-19  1.866557e-20
# 1    0.829021  1.191707e-02 -6.352013e-04
# 2    0.829787  2.367639e-02 -1.268383e-03
# 3    0.831154  3.527314e-02 -1.904871e-03
# 4    0.833199  4.671542e-02 -2.537746e-03

# %%
#sns.pairplot(df, size=2.5,palette="husl");

# %%
dfRun0 = [dfvRun00,dfvRun01, dfvRun02,dfvRun03,dfvRun04,dfvRun05,dfvRun06, dfvRun07,dfvRun08,dfvRun09,dfvRun010,dfvRun011]
df_avg_dfRun0 = pd.concat([each.stack() for each in dfRun0],axis=1)\
             .apply(lambda x:x.mean(),axis=1)\
             .unstack()

df_avg_dfRun0.columns = ['point', 'x','y','z']
df_avg_dfRun0['yp'] = ((0.4995-df_avg_dfRun0.point)*361)*2
df_avg_dfRun0['u'] = (df_avg_dfRun0.z)*(5850/361)
df_avg_dfRun0['xx'] = (df_avg_dfRun0.x)*(5850/361)
df_avg_dfRun0['yy'] = (df_avg_dfRun0.y)*(5850/361)
df_avg_dfRun0.tail()
# Out:
#       point             x         y         z            yp         u  \
# 229  0.4935 -1.089370e-07 -0.000017  0.075169  4.332000e+00  1.218106
# 230  0.4950 -5.129637e-07 -0.000007  0.064124  3.249000e+00  1.039132
# 231  0.4965 -3.756147e-08 -0.000008  0.039949  2.166000e+00  0.647381
# 232  0.4980  2.046372e-08 -0.000003  0.013191  1.083000e+00  0.213753
# 233  0.4995  0.000000e+00  0.000000  0.000000 -4.007905e-14  0.000000
#
#                xx        yy
# 229 -1.765322e-06 -0.000278
# 230 -8.312569e-06 -0.000106
# 231 -6.086831e-07 -0.000137
# 232  3.316143e-07 -0.000045
# 233  0.000000e+00  0.000000

# %%
dfv = [dfv0,dfv1, dfv2,dfv3,dfv4,dfv5,dfv6, dfv7,dfv8,dfv9,dfv10,dfv11]
df_avg = pd.concat([each.stack() for each in dfv],axis=1)\
             .apply(lambda x:x.mean(),axis=1)\
             .unstack()

df_avg.columns = ['point', 'x','y','z']
df_avg.head(100)
# Out:
#       point         x         y         z
# 0   0.00000  0.000088  0.001889  1.268147
# 1   0.00875 -0.000109 -0.000254  1.268035
# 2   0.01250 -0.000150 -0.000366  1.267920
# 3   0.02625 -0.000106 -0.000576  1.267077
# 4   0.02750 -0.000125 -0.000628  1.266962
# ..      ...       ...       ...       ...
# 95  0.26500 -0.001456  0.000734  1.173771
# 96  0.26625 -0.000503 -0.000410  1.175082
# 97  0.27000 -0.000935  0.000082  1.171970
# 98  0.27125 -0.000922  0.000092  1.170968
# 99  0.27625  0.000439 -0.000759  1.170361
#
# [100 rows x 4 columns]

# %%
#dfv1['yp'] = ((1-dfv1.point)*361)
#dfv1['u'] = (dfv1.z)*(5850/361)

# %%
df_avg['yp'] = (((0.5-df_avg.point)*361))*2
df_avg['u'] = (df_avg.z)*(5850/361)
df_avg['xx'] = (df_avg.x)*(5850/361)
df_avg['yy'] = (df_avg.y)*(5850/361)
df_avg.tail()
# Out:
#        point             x         y         z      yp         u        xx  \
# 262  0.49500 -1.146538e-05 -0.000057  0.110571  3.6100  1.791799 -0.000186
# 263  0.49625  2.347021e-06 -0.000039  0.071482  2.7075  1.158358  0.000038
# 264  0.49750 -3.282835e-06 -0.000030  0.057138  1.8050  0.925926 -0.000053
# 265  0.49875  2.083713e-07 -0.000008  0.013938  0.9025  0.225862  0.000003
# 266  0.50000  0.000000e+00  0.000000  0.000000  0.0000  0.000000  0.000000
#
#            yy
# 262 -0.000926
# 263 -0.000630
# 264 -0.000480
# 265 -0.000131
# 266  0.000000

# %%
ax = plt.gca()
# Set x logaritmic
ax.set_xscale('log')
plt.plot(df_avg_dfRun0.yp,df_avg_dfRun0.u,color ='green')
plt.plot(df_avg.yp,df_avg.u,color ='blue')
plt.plot(df_avg_dfRun2.yp,df_avg_dfRun2.u,color ='black')
plt.plot(df.OneMin_rPlus,df.UzPlus, color ='red')
plt.legend(['simulation1','simulation2','simulation3','El Koury'], ncol=2, loc='upper left');
plt.ylabel('Uz+')
plt.xlabel('(1-r)+')
# Out:
# Text(0.5, 0, '(1-r)+')

# %%
ax = plt.gca()
# Set x logaritmic
#ax.set_xscale('log')
plt.plot(df_avg_dfRun0.yp,df_avg_dfRun0.u,color ='green')
plt.plot(df_avg.yp,df_avg.u,color ='blue')
plt.plot(df_avg_dfRun2.yp,df_avg_dfRun2.u,color ='black')
plt.plot(df.OneMin_rPlus,df.UzPlus, color ='red')
plt.legend(['simulation1','simulation2', 'simulation3', 'El Koury'], ncol=2, loc='lower right');
plt.ylabel('Uz+')
plt.xlabel('(1-r)+')
# Out:
# Text(0.5, 0, '(1-r)+')

# %%
yp, u =df_avg.yp,df_avg.u

# %%
ax = plt.gca()
ax.set_xscale('log')
plt.plot(df_avg_dfRun2.yp,df_avg_dfRun2.u,color ='black')
plt.plot(df.OneMin_rPlus,df.UzPlus, color ='red')
plt.ylabel('Uz+')
plt.xlabel('(1-r)+')

plt.legend(['simulation3', 'El Koury'], ncol=2, loc='upper left');

# %%
#sns.pairplot(df_avg_rms, size=2.5,palette="husl");

# %%
#sns.pairplot(df, size=2.5,palette="husl");

# %% [markdown]
# # RMS

# %%
dfrms = [dfrms0,dfrms1, dfrms2,dfrms3,dfrms4,dfrms5,dfrms6, dfrms7,dfrms8,dfrms9,dfrms10,dfrms11]
df_avg_rms = pd.concat([each.stack() for each in dfrms],axis=1)\
             .apply(lambda x:x.mean(),axis=1)\
             .unstack()

df_avg_rms.columns = ['point', 'x','y','z','men']
df_avg_rms.head(100)
# Out:
#       point         x         y         z       men
# 0   0.00000  0.042072  0.041870  0.056068  0.000065
# 1   0.00875  0.042012  0.042061  0.056151  0.000069
# 2   0.01250  0.041969  0.042128  0.056235  0.000096
# 3   0.02625  0.042083  0.042366  0.056616  0.000210
# 4   0.02750  0.042076  0.042419  0.056695  0.000219
# ..      ...       ...       ...       ...       ...
# 95  0.26500  0.050654  0.056219  0.092711  0.002128
# 96  0.26625  0.050647  0.056185  0.093163  0.002127
# 97  0.27000  0.050931  0.056466  0.094232  0.002168
# 98  0.27125  0.050852  0.056551  0.094194  0.002167
# 99  0.27625  0.050858  0.057137  0.095049  0.002178
#
# [100 rows x 5 columns]

# %%
df.head()
# Out:
#    OneMin_r  OneMin_rPlus     UzPlus    UzByUb  Ur_rmsPlus  Ut_rmsPlus  \
# 0  1.000000    361.217889  20.605459  1.272318    0.670160    0.670160
# 1  0.987453    356.685512  20.604020  1.272229    0.670291    0.670406
# 2  0.975062    352.209927  20.599764  1.271966    0.670682    0.671152
# 3  0.962827    347.790423  20.592756  1.271534    0.671335    0.672413
# 4  0.950746    343.426295  20.583060  1.270935    0.672246    0.674192
#
#    Uz_rmsPlus      UzUrPlus     dUzdrPlus
# 0    0.828781  6.291752e-19  1.866557e-20
# 1    0.829021  1.191707e-02 -6.352013e-04
# 2    0.829787  2.367639e-02 -1.268383e-03
# 3    0.831154  3.527314e-02 -1.904871e-03
# 4    0.833199  4.671542e-02 -2.537746e-03

# %%
df_avg_rms['yrms'] = ((0.5-df_avg_rms.point)*360)*2
df_avg_rms['uzrms'] = df_avg_rms.z *(5850/360)
df_avg_rms['uxrms'] = df_avg_rms.x *(5850/360)
df_avg_rms['uyrms'] = df_avg_rms.y *(5850/360)
#df_avg_rms['umenrms'] = df_avg_rms.men *(5850/361)
df_avg_rms['umenrms'] = np.sqrt(df_avg_rms.men)*(5850/360)

# %%
# df_avg_rms['yrms'] = (0.5-df_avg_rms.point)*361
# df_avg_rms['uzrms'] = np.sqrt(df_avg_rms.z)*(5850/361)
# df_avg_rms['uxrms'] = np.sqrt(df_avg_rms.x)*(5850/361)
# df_avg_rms['uyrms'] = np.sqrt(df_avg_rms.y)*(5850/361)
# df_avg_rms['umenrms'] = np.sqrt(df_avg_rms.men)*(5850/361)

# %%
df_avg_rms.head()
# Out:
#      point         x         y         z       men   yrms     uzrms     uxrms  \
# 0  0.00000  0.042072  0.041870  0.056068  0.000065  360.0  0.911108  0.683667
# 1  0.00875  0.042012  0.042061  0.056151  0.000069  353.7  0.912450  0.682687
# 2  0.01250  0.041969  0.042128  0.056235  0.000096  351.0  0.913819  0.682001
# 3  0.02625  0.042083  0.042366  0.056616  0.000210  341.1  0.920005  0.683855
# 4  0.02750  0.042076  0.042419  0.056695  0.000219  340.2  0.921291  0.683732
#
#       uyrms   umenrms
# 0  0.680389  0.130551
# 1  0.683488  0.134701
# 2  0.684587  0.158836
# 3  0.688452  0.235593
# 4  0.689303  0.240396

# %%
ax = plt.gca()
# Set x logaritmic
ax.set_xscale('log')
plt.plot(df_avg_rms.yrms,df_avg_rms.uzrms,color ='blue')

plt.plot(df.OneMin_rPlus,df.Uz_rmsPlus, color ='red')


plt.legend('a', ncol=2, loc='upper left');
plt.ylabel('Uz+,rms')
plt.xlabel('(1-r)+')
plt.legend(['simulation2', 'El Koury'],  loc='upper left');

# %%
plt.plot(df_avg_rms.yrms,df_avg_rms.uzrms,color ='blue')
plt.plot(df.OneMin_rPlus,df.Uz_rmsPlus, color ='red')
plt.legend('a', ncol=2, loc='upper left');
plt.ylabel('Uz+,rms')
plt.xlabel('(1-r)+')
plt.legend(['simulation2', 'El Koury'],  loc='upper right');

# %%
ax = plt.gca()
# Set x logaritmic
ax.set_xscale('log')
plt.plot(df_avg_rms.yrms,df_avg_rms.uyrms,color ='blue')
plt.plot(df.OneMin_rPlus,df.Ur_rmsPlus, color ='red')
plt.legend('a', ncol=2, loc='upper left');
plt.ylabel('Ur+, rms')
plt.xlabel('(1-r)+')
plt.legend(['simulation2', 'El Koury'],  loc='upper left');

# %%
ax = plt.gca()
# Set x logaritmic
#ax.set_xscale('log')
plt.plot(df_avg_rms.yrms,df_avg_rms.uyrms,color ='blue')
plt.plot(df.OneMin_rPlus,df.Ur_rmsPlus, color ='red')
plt.legend('a', ncol=2, loc='upper left');
plt.ylabel('Ur+')
plt.xlabel('(1-r)+')
plt.legend(['simulation2', 'El Koury'],  loc='lower right');

# %%
ax = plt.gca()
# Set x logaritmic
ax.set_xscale('log')

plt.plot(df_avg_rms.yrms,df_avg_rms.umenrms,color ='blue')
plt.plot(df.OneMin_rPlus,df.UzUrPlus, color ='red')
plt.ylabel('<uz,ur>+')
plt.xlabel('(1-r)+')
plt.legend(['simulation2', 'El Koury'],  loc='upper left');

# %%
#plt.plot(df_avg_rms.yrms,df_avg_rms.uzrms,color ='blue')

# %%
plt.plot(df.OneMin_rPlus,df.UzUrPlus, color ='red')
plt.plot(df_avg_rms.yrms,df_avg_rms.umenrms,color ='blue')
plt.legend('a', ncol=2, loc='upper left');
plt.ylabel('<uz,ur>+')
plt.xlabel('(1-r)+')
plt.legend(['simulation2', 'El Koury'],  loc='upper right');

# %% [markdown]
# # Experimenting

# %%
ax = plt.gca()
# Set x logaritmic
ax.set_xscale('log')
plt.plot(df_avg.yp,df_avg.yy,color ='blue')
#plt.plot(df.OneMin_rPlus,df.UzPlus, color ='gray')
plt.legend('a', ncol=2, loc='upper left');
plt.ylabel('Uz+')
plt.xlabel('(1-r)+')

# %%
ax = sns.regplot(x="yp", y="u", data=df_avg)
sns.kdeplot(df_avg.yp,df_avg.u)
#ax.set_xscale('log')

# %%
#for angle in range(70,210,2):
df_avg.head()

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

#ax = plt.gca()
# Set x logaritmic

fig = plt.figure()
ax = fig.gca(projection='3d')
#ax.set_xscale('log')

ax.plot_trisurf(df_avg.yp,df_avg.u,df_avg.yy, cmap=plt.cm.jet, linewidth=0.1)

ax.set_zscale('log')
#ax.set_scale('log')
plt.show()


#ax.view_init(30,angle)

# %%
df.columns

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')
#ax.set_xscale('log')

ax.plot_trisurf(df.OneMin_rPlus,df.UzByUb,df.UzPlus, cmap=plt.cm.jet, linewidth=0.1)
plt.show()

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot_trisurf(df_avg.xx,df_avg.yy,df_avg.point, cmap=plt.cm.viridis, linewidth=0.2)

# %%
df_avg.columns

# %%
df_avg_rms.columns

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df_avg.xx,df_avg.yy,df_avg.u, c='skyblue', s=60)
ax.view_init(30, 185)
plt.show()
