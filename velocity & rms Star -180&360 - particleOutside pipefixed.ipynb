# %% [markdown]
# # Beseme Selasa

# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set(style="ticks", color_codes=True)
import matplotlib.pyplot as plt
plt.style.use('classic')
# %matplotlib inline
import os
import glob
# path of the data
path = r'C:/Users/pmbw/Development/datasets' 
#Smoothing function
from scipy.ndimage.filters import gaussian_filter1d

# %%
#!pip install chart_studio

# %%
#import chart_studio.plotly as py

# %% [markdown]
# # Import Data

# %% [markdown]
# ## Velocities average for DNS datasets

# %% [markdown]
# # Previous DNS datasets

# %% [markdown]
# # Mean axial velocity $U_z^+$

# %%
# character description

# '-'       solid line style # '--'      dashed line style # '-.'      dash-dot line style
# ':'       dotted line style # '.'       point marker # ','       pixel marker
# 'o'       circle marker # 'v'       triangle_down marker # '^'       triangle_up marker
# '<'       triangle_left marker # '>'       triangle_right marker # '1'       tri_down marker
# '2'       tri_up marker # '3'       tri_left marker # '4'       tri_right marker
# 's'       square marker # 'p'       pentagon marker # '*'       star marker
# 'h'       hexagon1 marker # 'H'       hexagon2 marker # '+'       plus marker
# 'x'       x marker # 'D'       diamond marker # 'd'       thin_diamond marker
# '|'       vline marker # '_'       hline marker

# %%
sarma = pd.read_csv('C:/Users/pmbw/Development/datasets/particles/restrted/sarmamean2.txt',
            skiprows=1, sep='\s+', engine='python') 
partstatVwork = pd.read_csv('C:/Users/pmbw/Development/datasets/particles/Vpipe180/runsfine_atetkemew/partstat00009.txt',
         skiprows =1,  sep='\s+', engine='python')
vreman = pd.read_csv('C:/Users/pmbw/Development/datasets/particles/\VremanData/vreman246d.txt',
            skiprows=1, sep='\s+', engine='python')

# %% [markdown]
# # 360

# %%
ax = plt.gca()
# Set x logaritmic
#ax.set_xscale('log')
#plt.xlim(0.01,1)
#plt.ylim(0,25)
plt.plot((sarma.r)*2,sarma.ave/14.229, color = 'black',linewidth=1, markersize=1)
#plt.plot((vreman.r),vreman.ave, color = 'black',linewidth=1, markersize=1)

#plt.plot(partstatV.y*2,partstatV.w*15.1,color ='blue', linewidth=1, markersize=1)
plt.plot(partstatVwork.y*2,partstatVwork.w,'--', color ='blue', linewidth=3, markersize=4)
#plt.plot(partstatVv.y,partstatVv.w,color ='red', linewidth=1, markersize=10)
#plt.plot(partstatV.y,np.sqrt(partstatV.v2),color ='blue', linewidth=1, markersize=1)
#plt.plot((VremanData[0]),VremanData[4],color ='red', linewidth=1, markersize=1)
#plt.plot((VremanData.r),VremanData.ave,color ='red', linewidth=1, markersize=1)
plt.title('Mean particle and fluid axial velocity profile', fontsize = 22)
plt.ylabel('$u_z^*$',fontsize=22)
plt.xlabel('$(1-r)^*$' ,fontsize=18)
# Out:
# Text(0.5, 0, '$(1-r)^*$')

# %%
partstatV = pd.read_csv('C:/Users/pmbw/Development/datasets/particles/Vpipe180/withoutG/partstat02000.txt',
           skiprows =1, sep='\s+', engine='python')
vremanrms = pd.read_csv('C:/Users/pmbw/Development/datasets/particles/VremanData/vreman247rmsd.txt',
          skiprows =1, sep='\s+', engine='python')
ax = plt.gca()
# Set x logaritmic
#ax.set_xscale('log')
#plt.xlim(0.01,1)
#plt.ylim(0,25)
plt.plot((sarma.r)*2,sarma.ave/15.5229, color = 'black',linewidth=1, markersize=1)
plt.plot(partstatV.y*2,partstatV.w,color ='blue', linewidth=1, markersize=1)
plt.title('Mean particle profile  - 360 ', fontsize = 22)
plt.ylabel('$u_z^*$',fontsize=22)
plt.xlabel('$(1-r)^*$' ,fontsize=18)
# Out:
# Text(0.5, 0, '$(1-r)^*$')

# %%
partstatvreman = pd.read_csv('C:/Users/pmbw/Development/datasets/particles/Vpipe180/partstat02000.txt',
           skiprows =1, sep='\s+', engine='python')
v247 = pd.read_csv('C:/Users/pmbw/Development/datasets/particles/VremanData/vreman246dNotThick.txt',
          skiprows =1, sep='\s+', engine='python')
ax = plt.gca()
# Set x logaritmic
#ax.set_xscale('log')
#plt.xlim(0.01,1)
#plt.ylim(0,25)
#plt.plot((sarma.r)*2,sarma.ave/14.35229, color = 'black',linewidth=1, markersize=1)
plt.plot(partstatvreman.y*2,partstatvreman.w,color ='red', linewidth=1, markersize=1)
plt.plot(v247.r,v247.ave*1.5212,color ='blue', linewidth=1, markersize=1)
plt.title('Mean particle profile - 180' , fontsize = 22)
plt.ylabel('$u_z^*$',fontsize=22)
plt.xlabel('$(1-r)^*$' ,fontsize=18)
# Out:
# Text(0.5, 0, '$(1-r)^*$')

# %%
pwd
# Out:
# 'C:\\Users\\pmbw\\Development\\code'
